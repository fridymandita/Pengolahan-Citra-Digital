# %% [markdown]
# <a href="https://colab.research.google.com/github/fridymandita/Pengolahan-Citra-Digital/blob/main/PCD_Negative_Image.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Load Image

# %%
from google.colab import files
file = files.upload()
# Out:
#      <input type="file" id="files-082a722c-e4d0-4fdd-bcb2-c471fe8063dc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-082a722c-e4d0-4fdd-bcb2-c471fe8063dc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving ferrari.jpg to ferrari.jpg

# %% [markdown]
# # Load Library

# %%
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# #Convert Image ke RGB

# %%
img = cv2.imread('ferrari.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %% [markdown]
# #Baca Image ke Grayscale

# %%
gray = cv2.imread('ferrari.jpg', 0)

# %% [markdown]
# #Generate Negative Image

# %%
colored_negative = abs(255-img)
gray_negative = abs(255-gray)

# %% [markdown]
# #Plot Result Negative Image

# %%
imgs = [img, gray, colored_negative, gray_negative]
title = ['coloured', 'gray', 'coloured-negative', 'gray-negative']


plt.subplot(2, 2, 1)
plt.title(title[0])
plt.imshow(imgs[0])
plt.xticks([])
plt.yticks([])

plt.subplot(2, 2, 2)
plt.title(title[1])
plt.imshow(imgs[1], cmap='gray')
plt.xticks([])
plt.yticks([])

plt.subplot(2, 2, 3)
plt.title(title[2])
plt.imshow(imgs[2])
plt.xticks([])
plt.yticks([])

plt.subplot(2, 2, 4)
plt.title(title[3])
plt.imshow(imgs[3], cmap='gray')
plt.xticks([])
plt.yticks([])

plt.show()
